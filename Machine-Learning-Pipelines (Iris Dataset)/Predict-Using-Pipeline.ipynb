# %%
import pickle
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
pipe = pickle.load(open('pipe.pkl', 'rb'))

# %%
test_input = np.array([6.3, 2.1, 3.4, 0.2]).reshape(1, 4)

# %%
result = pipe.predict(test_input)
print("Species:",result[0])
# Out:
# Species: Iris-versicolor
